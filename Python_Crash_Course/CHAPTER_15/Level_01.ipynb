# %% [markdown]
# ### Welcome to Generating Data

# %%
#First import matplotlib
import matplotlib.pyplot as plt

#Declear a variable that hold the data of what you want to plot
squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(squares)

plt.show()

# %%
#Imort Matplotlib

import matplotlib.pyplot as viz

#Declare a variable

numbers = [2,9,10,14,58,50]

#Unpacked the turple
fig, ac = viz.subplots()

#Let it plot
ac.plot(numbers)
viz.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
